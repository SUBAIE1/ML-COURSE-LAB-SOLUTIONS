# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#loading dataset
ds = pd.read_csv("/Users/subaie/projects/my_python_project/machine_learning/customer_segmentation_mixed.csv")

# %%
#displaying the shape
ds.shape
# Out:
# (350, 6)

# %%
#displaying the first 5 rows
ds.head()
# Out:
#    Age  Annual_Income  Spending_Score  Monthly_Visits  Gender  \
# 0   56          26102              85               6  Female
# 1   46          70336              75              18    Male
# 2   32         105314              36              10    Male
# 3   60          46641              99               5  Female
# 4   25          54584              19              10    Male
#
#   Preferred_Product
# 0          Clothing
# 1              Home
# 2         Groceries
# 3       Electronics
# 4       Electronics

# %%
#checking column names
ds.columns
# Out:
# Index(['Age', 'Annual_Income', 'Spending_Score', 'Monthly_Visits', 'Gender',
#        'Preferred_Product'],
#       dtype='object')

# %%
#checking datatypes
ds.dtypes
# Out:
# Age                   int64
# Annual_Income         int64
# Spending_Score        int64
# Monthly_Visits        int64
# Gender               object
# Preferred_Product    object
# dtype: object
